# %% [markdown]
# ### 1-1. urllib.request 사용
#
# urllib으로 웹 사이트에서 데이터를 읽어들이고 파일로 저장하는 방법<br>
# urllib를 이용하면 간단하게 데이터를 다운로드할 수 있다.<br>
#
# 기상청 RSS 데이터를 이용해 특정 지역코드를 입력하면 그 지 역의 날씨를 얻는 py 파일 생성

# %%
# %%HTML
# <video width="640" height="480" controls>
#   <source src="1-1.날씨.mp4" type="video/mp4">
# </video>
# Out:
# <video width="640" height="480" controls>
#   <source src="1-1.날씨.mp4" type="video/mp4">
# </video>

# %% [markdown]
# #### urlretrieve 사용

# %%
import urllib.request

#URL과 저장경로 지정하기
url = "http://uta.pw/shodou/img/28/214.png"
savename = "test.png"

# %%
# 다운로드
urllib.request.urlretrieve(url, savename)
print("저장완료")
# Out:
# 저장완료

# %% [markdown]
# _______

# %% [markdown]
# #### urlopen() 사용
#
# 메모리에 올린 후 저장

# %%
import urllib.request

#URL과 저장경로 지정하기
url = "http://uta.pw/shodou/img/28/214.png"
savename = "test.png"

# %%
# 다운로드
mem = urllib.request.urlopen(url).read()

# 파일로 저장하기
with open(savename, mode="wb") as f:   #wb 쓰기모드, 바이너리
    f.write(mem)
    print("저장완료")
# Out:
# 저장완료

# %% [markdown]
# ________

# %% [markdown]
# #### 웹에서 데이터 추출

# %%
# IP 확인 API로 접근해서 결과 출력하기
import urllib.request

#데이터 읽어들이기
url = "http://api.aoikujira.com/ip/ini"
res = urllib.request.urlopen(url)
data = res.read()

# 바이너리를 문자열로 변환하기
text = data.decode("utf-8")
print(text)

# %% [markdown]
# _______

# %% [markdown]
# #### 매개변수를 추가해 날씨 요청을 전송하기, 기상청RSS활용

# %%
import urllib.request
import urllib.parse

# 매개변수를 URL 인코딩
API = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"

values = {
    'stnId': '184'
}

params = parse.urlencode(values)
url = API + "?" + params

# %% [markdown]
# #### stnID 에 지역코드 입력
# 1. 전국 : 108
# 2. 서울/경기도 : 109
# 3. 강원도 : 105
# 4. 충청북도 : 131
# 5. 충청남도 : 133
# 6. 전라북도 : 146
# 7. 전라남도 : 156
# 8. 경상북도 : 143
# 9. 경상남도 : 159
# 10. 제주도 : 184

# %%
# 요청 전용 URL을 생성합니다.
url = API + "?" + params
print("url=", url)

# 다운로드합니다.
data = urllib.request.urlopen(url).read()
text = data.decode("utf-8")

print(text)
# Out:
# url= http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=184
# <?xml version="1.0" encoding="utf-8" ?>
# <rss version="2.0">
# <channel>
# <title>기상청 육상 중기예보</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_07.jsp</link>
# <description>기상청 날씨 웹서비스</description>
# <language>ko</language>
# <generator>기상청</generator>
# <pubDate>2017년 09월 29일 (금)요일 18:00</pubDate>
#  <item>
# <author>기상청</author>
# <category>육상중기예보</category>
# <title>제주도 육상 중기예보 - 2017년 09월 29일 (금)요일 18:00 발표</title>
# <link>http://www.kma.go.kr/weather/forecast/mid-term_07.jsp</link>
# <guid>http://www.kma.go.kr/weather/forecast/mid-term_07.jsp</guid>
# <description>
# 	<header>
# 		<title>제주도 육상중기예보</title>
# 		<tm>201709291800</tm>
# ...

# %% [markdown]
# _____

# %% [markdown]
# #### 지역번호를 매개변수로 받기

# %%
# download-forecast-argv.py 파일 생성

# 라이브러리 읽기
import sys
import urllib.request as req
import urllib.parse as parse

# 명령줄 매개변수 추출
if len(sys.argv) <= 1:
    print("USAGE: download-forecast-argv <Region Number>")
    sys.exit()
regionNumber = sys.argv[1]

# 매개변수를 URL 인코딩
API = "http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp"

values = {
    'stnId': regionNumber
}

params = parse.urlencode(values)
url = API + "?" + params
print("url=", url)

# 다운로드합니다.
data = req.urlopen(url).read()
text = data.decode("utf-8")

print(text)
# Out:
# url= http://www.kma.go.kr/weather/forecast/mid-term-rss3.jsp?stnId=-f
